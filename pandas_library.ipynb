# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("movies.csv")

# %%
data
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
new_data=data.iloc[35:45]
new_data

#dataframe in içinden belirli bir kısmını slice ediyoruz
# Out:
#                                   Film    Genre            Lead Studio  \
# 35                   Not Easily Broken    Drama            Independent
# 36                     No Reservations   Comedy           Warner Bros.
# 37  Nick and Norah's Infinite Playlist   Comedy                   Sony
# 38                      New Year's Eve  Romance           Warner Bros.
# 39                My Week with Marilyn    Drama  The Weinstein Company
# 40                    Music and Lyrics  Romance           Warner Bros.
# 41                         Monte Carlo  Romance       20th Century Fox
# 42      Miss Pettigrew Lives for a Day   Comedy            Independent
# 43                   Midnight in Paris  Romence                   Sony
# 44                       Marley and Me   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 35                66       2.140000                 34         $10.70   2009
# ...

# %%
new_data.head()
# Out:
#                                   Film    Genre            Lead Studio  \
# 35                   Not Easily Broken    Drama            Independent
# 36                     No Reservations   Comedy           Warner Bros.
# 37  Nick and Norah's Infinite Playlist   Comedy                   Sony
# 38                      New Year's Eve  Romance           Warner Bros.
# 39                My Week with Marilyn    Drama  The Weinstein Company
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 35                66       2.140000                 34         $10.70   2009
# 36                64       3.307180                 39         $92.60   2007
# 37                67       3.352729                 73         $33.53   2008
# 38                48       2.536429                  8        $142.04   2011
# 39                84       0.825800                 83          $8.26   2011

# %%
new_data.tail()
# Out:
#                               Film    Genre       Lead Studio  \
# 40                Music and Lyrics  Romance      Warner Bros.
# 41                     Monte Carlo  Romance  20th Century Fox
# 42  Miss Pettigrew Lives for a Day   Comedy       Independent
# 43               Midnight in Paris  Romence              Sony
# 44                   Marley and Me   Comedy               Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 40                70       3.647411                 63        $145.90   2007
# 41                50       1.983200                 38         $39.66   2011
# 42                70       0.252895                 78         $15.17   2008
# 43                84       8.744706                 93        $148.66   2011
# 44                77       3.746782                 63        $206.07   2008

# %%
new_data.shape
# Out:
# (10, 8)

# %%
new_data.ndim
# Out:
# 2

# %%
new_data.describe()
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %        Year
# count         10.000000      10.000000          10.000000    10.00000
# mean          68.000000       3.053713          57.200000  2009.10000
# std           12.229291       2.319734          26.574006     1.72884
# min           48.000000       0.252895           8.000000  2007.00000
# 25%           64.500000       2.022400          38.250000  2008.00000
# 50%           68.500000       2.921804          63.000000  2008.50000
# 75%           75.250000       3.573740          76.750000  2011.00000
# max           84.000000       8.744706          93.000000  2011.00000

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 35 to 44
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               10 non-null     object
#  1   Genre              10 non-null     object
#  2   Lead Studio        10 non-null     object
#  3   Audience score %   10 non-null     int64
#  4   Profitability      10 non-null     float64
#  5   Rotten Tomatoes %  10 non-null     int64
#  6   Worldwide Gross    10 non-null     object
#  7   Year               10 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 772.0+ bytes

# %%
new_data["Year"]
#spesifik olarak bir columnda yer alan verileri getiriyor
# Out:
# 35    2009
# 36    2007
# 37    2008
# 38    2011
# 39    2011
# 40    2007
# 41    2011
# 42    2008
# 43    2011
# 44    2008
# Name: Year, dtype: int64

# %%
new_data.size
# Out:
# 80

# %%
new_data1=new_data.drop(["Audience score %","Profitability","Rotten Tomatoes %"],axis=1)

#Audience score % ve Profitability kolonlarını sildik

# %%
films=np.array(["A Beautiful Mind"," American Beauty","Godfather","Big Fish","Blade Runner","Blue Velvet",
                "Clockwork Orange","Dog Day Afternoon","Full Metal Jacket","Lord of The Rings"])
genres=np.array(["Drama","Romance","Drama","Romance",",Science Fiction","Romance","Dram","Dram","Action","Fantastic"])

lead_studios=np.array(["Warner Bros.","Warner Bros.","Sony","Warner Bros.","Warner Bros.","Independent",
                      "Independent","Sony","Independent","Warner Bros."])

gross=np.array([100000,200000,1000000,150000,1000000,50000,20000,500000,10000,10000000])

# %%
dictionary={"Film":films,
           "Genre":genres,
           "Lead Studio":lead_studios,
           "Worldwide Gross":gross,
           
           }

# %%
current_year=pd.DataFrame(dictionary)
current_year.head()
# Out:
#                Film             Genre   Lead Studio  Worldwide Gross
# 0  A Beautiful Mind             Drama  Warner Bros.           100000
# 1   American Beauty           Romance  Warner Bros.           200000
# 2         Godfather             Drama          Sony          1000000
# 3          Big Fish           Romance  Warner Bros.           150000
# 4      Blade Runner  ,Science Fiction  Warner Bros.          1000000

# %%
current_year["Year"]=2023
current_year
# Out:
#                 Film             Genre   Lead Studio  Worldwide Gross  Year
# 0   A Beautiful Mind             Drama  Warner Bros.           100000  2023
# 1    American Beauty           Romance  Warner Bros.           200000  2023
# 2          Godfather             Drama          Sony          1000000  2023
# 3           Big Fish           Romance  Warner Bros.           150000  2023
# 4       Blade Runner  ,Science Fiction  Warner Bros.          1000000  2023
# 5        Blue Velvet           Romance   Independent            50000  2023
# 6   Clockwork Orange              Dram   Independent            20000  2023
# 7  Dog Day Afternoon              Dram          Sony           500000  2023
# 8  Full Metal Jacket            Action   Independent            10000  2023
# 9  Lord of The Rings         Fantastic  Warner Bros.         10000000  2023

# %%
current_year.head()
# Out:
#                Film             Genre   Lead Studio  Worldwide Gross  Year
# 0  A Beautiful Mind             Drama  Warner Bros.           100000  2023
# 1   American Beauty           Romance  Warner Bros.           200000  2023
# 2         Godfather             Drama          Sony          1000000  2023
# 3          Big Fish           Romance  Warner Bros.           150000  2023
# 4      Blade Runner  ,Science Fiction  Warner Bros.          1000000  2023

# %%
new_data1.head()
# Out:
#                                   Film    Genre            Lead Studio  \
# 35                   Not Easily Broken    Drama            Independent
# 36                     No Reservations   Comedy           Warner Bros.
# 37  Nick and Norah's Infinite Playlist   Comedy                   Sony
# 38                      New Year's Eve  Romance           Warner Bros.
# 39                My Week with Marilyn    Drama  The Weinstein Company
#
#    Worldwide Gross  Year
# 35         $10.70   2009
# 36         $92.60   2007
# 37         $33.53   2008
# 38        $142.04   2011
# 39          $8.26   2011

# %%
concat_data=pd.concat([new_data1,current_year],axis=0)

concat_data
# Out:
#                                   Film             Genre  \
# 35                   Not Easily Broken             Drama
# 36                     No Reservations            Comedy
# 37  Nick and Norah's Infinite Playlist            Comedy
# 38                      New Year's Eve           Romance
# 39                My Week with Marilyn             Drama
# 40                    Music and Lyrics           Romance
# 41                         Monte Carlo           Romance
# 42      Miss Pettigrew Lives for a Day            Comedy
# 43                   Midnight in Paris           Romence
# 44                       Marley and Me            Comedy
# 0                     A Beautiful Mind             Drama
# 1                      American Beauty           Romance
# 2                            Godfather             Drama
# 3                             Big Fish           Romance
# 4                         Blade Runner  ,Science Fiction
# ...

# %%
concat_data.reset_index(drop=True,inplace=True)

concat_data
# Out:
#                                   Film             Genre  \
# 0                    Not Easily Broken             Drama
# 1                      No Reservations            Comedy
# 2   Nick and Norah's Infinite Playlist            Comedy
# 3                       New Year's Eve           Romance
# 4                 My Week with Marilyn             Drama
# 5                     Music and Lyrics           Romance
# 6                          Monte Carlo           Romance
# 7       Miss Pettigrew Lives for a Day            Comedy
# 8                    Midnight in Paris           Romence
# 9                        Marley and Me            Comedy
# 10                    A Beautiful Mind             Drama
# 11                     American Beauty           Romance
# 12                           Godfather             Drama
# 13                            Big Fish           Romance
# 14                        Blade Runner  ,Science Fiction
# ...

# %%
concat_data.isna().any()
# Out:
# Film               False
# Genre              False
# Lead Studio        False
# Worldwide Gross    False
# Year               False
# dtype: bool

# %%
concat_data.fillna(value=np.mean(concat_data),inplace=True)
concat_data
# Out:
#                                   Film             Genre  \
# 0                    Not Easily Broken             Drama
# 1                      No Reservations            Comedy
# 2   Nick and Norah's Infinite Playlist            Comedy
# 3                       New Year's Eve           Romance
# 4                 My Week with Marilyn             Drama
# 5                     Music and Lyrics           Romance
# 6                          Monte Carlo           Romance
# 7       Miss Pettigrew Lives for a Day            Comedy
# 8                    Midnight in Paris           Romence
# 9                        Marley and Me            Comedy
# 10                    A Beautiful Mind             Drama
# 11                     American Beauty           Romance
# 12                           Godfather             Drama
# 13                            Big Fish           Romance
# 14                        Blade Runner  ,Science Fiction
# ...

# %%
concat_data
# Out:
#                                   Film             Genre  \
# 0                    Not Easily Broken             Drama
# 1                      No Reservations            Comedy
# 2   Nick and Norah's Infinite Playlist            Comedy
# 3                       New Year's Eve           Romance
# 4                 My Week with Marilyn             Drama
# 5                     Music and Lyrics           Romance
# 6                          Monte Carlo           Romance
# 7       Miss Pettigrew Lives for a Day            Comedy
# 8                    Midnight in Paris           Romence
# 9                        Marley and Me            Comedy
# 10                    A Beautiful Mind             Drama
# 11                     American Beauty           Romance
# 12                           Godfather             Drama
# 13                            Big Fish           Romance
# 14                        Blade Runner  ,Science Fiction
# ...

# %%
concat_data.describe()
# Out:
#               Year
# count    20.000000
# mean   2016.050000
# std       7.229144
# min    2007.000000
# 25%    2008.750000
# 50%    2017.000000
# 75%    2023.000000
# max    2023.000000

# %%
concat_data[concat_data["Year"]==2023].describe()
# Out:
#          Year
# count    10.0
# mean   2023.0
# std       0.0
# min    2023.0
# 25%    2023.0
# 50%    2023.0
# 75%    2023.0
# max    2023.0

# %%
concat_data.sort_values(by="Year")
# Out:
#                                   Film             Genre  \
# 1                      No Reservations            Comedy
# 5                     Music and Lyrics           Romance
# 9                        Marley and Me            Comedy
# 2   Nick and Norah's Infinite Playlist            Comedy
# 7       Miss Pettigrew Lives for a Day            Comedy
# 0                    Not Easily Broken             Drama
# 6                          Monte Carlo           Romance
# 3                       New Year's Eve           Romance
# 8                    Midnight in Paris           Romence
# 4                 My Week with Marilyn             Drama
# 18                   Full Metal Jacket            Action
# 10                    A Beautiful Mind             Drama
# 11                     American Beauty           Romance
# 12                           Godfather             Drama
# 13                            Big Fish           Romance
# ...

# %%
concat_data[concat_data["Year"]==2011].sort_values(by="Lead Studio")
# Out:
#                    Film    Genre            Lead Studio Worldwide Gross  Year
# 6           Monte Carlo  Romance       20th Century Fox         $39.66   2011
# 8     Midnight in Paris  Romence                   Sony        $148.66   2011
# 4  My Week with Marilyn    Drama  The Weinstein Company          $8.26   2011
# 3        New Year's Eve  Romance           Warner Bros.        $142.04   2011

# %%
concat_data["Film"].value_counts()
# Out:
# Blade Runner                          1
# No Reservations                       1
# Lord of The Rings                     1
# Blue Velvet                           1
# Godfather                             1
# Clockwork Orange                      1
# Not Easily Broken                     1
#  American Beauty                      1
# New Year's Eve                        1
# My Week with Marilyn                  1
# Nick and Norah's Infinite Playlist    1
# A Beautiful Mind                      1
# Dog Day Afternoon                     1
# Music and Lyrics                      1
# Big Fish                              1
# Miss Pettigrew Lives for a Day        1
# Midnight in Paris                     1
# Marley and Me                         1
# Monte Carlo                           1
# Full Metal Jacket                     1
# Name: Film, dtype: int64
