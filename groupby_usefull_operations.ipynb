# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Basic Aggregation Methods

# %% [raw]
# En temel analiz işlevlerinden biri, verileri gruplamak ve bir araya getirmektir. Bazı durumlarda, bu analiz düzeyi, gerçek dünya/iş sorularını yanıtlamak için yeterli olabilir. Diğer durumlarda, bu aktivite daha karmaşık bir veri bilimi analizinde ilk adım olabilir.
#
# Pandas, groupby işlevi, verileri hızlı ve kolay bir şekilde özetlemek için bir veya daha fazla toplama işleviyle birleştirilebilir.

# %% [markdown]
# Büyük verilerin analizinin önemli bir parçası verimli özetlemedir: tek bir sayının bir verinin doğasına ilişkin fikir verdiği sum(), mean(), median(), min() ve max() gibi bilgi işlem toplamaları.
#
# potansiyel olarak büyük veri kümesi. aggregate() yöntemi, index (satır) ekseni Kaynağı olan DataFrame'in eksenlerinden biri boyunca yürütülecek bir işlev veya işlev adları listesi uygulamanıza izin verir, varsayılan 0'dır.
#
# Genellikle büyük miktarda veriyle karşılaşıldığında ilk adım, söz konusu veriler için özet istatistikleri hesaplamaktır. Belki de en yaygın özet istatistikleri, bir veri kümesindeki "typical" değerleri özetlemenize izin veren ortalama ve standart sapmadır, ancak diğer toplamalar da yararlıdır (toplam, çarpım, medyan, minimum ve maksimum, nicelikler vb. ).

# %% [raw]
# NumPy has fast built-in aggregation functions for working on arrays which are also used for Pandas Dataframes Pandas Official Documentation; we'll discuss and demonstrate some of them here:
#
# count() ==> Counts non-NA cells for each column or row.
# mean() ==> Returns the mean of the values over the requested axis.
# median() ==> Returns the median of the values over the requested axis.
# min() ==> Returns the minimum of the values over the requested axis.
# max() ==> Returns the maximum of the values over the requested axis.
# std() ==> Returns sample standard deviation over requested axis.
# var() ==> Returns unbiased variance over requested axis.
# sum() ==> Returns the sum of the values over the requested axis.
# idxmin() ==> Returns index of first occurrence of minimum over requested axis.
# idxmax() ==> Returns index of first occurrence of maximum over requested axis.
# corr() ==> Computes pairwise correlation of columns, excluding NA/null values.

# %%
df= pd.DataFrame(np.random.randint(0,100 , size=(7,5)),
                columns=["x1","x2","x3","x4","x5"])

df
# Out:
#    x1  x2  x3  x4  x5
# 0  37  37  15  92  43
# 1  50  33  39   5  41
# 2  33  82  19  26  95
# 3  87  13  53  50  53
# 4   0  39   6   6  50
# 5   3  69  63  28  48
# 6  10  43  15  60  66

# %%
df.count()
# Out:
# x1    7
# x2    7
# x3    7
# x4    7
# x5    7
# dtype: int64

# %%
df["x1"]
# Out:
# 0    37
# 1    50
# 2    33
# 3    87
# 4     0
# 5     3
# 6    10
# Name: x1, dtype: int32

# %%
df["x1"].count()
# Out:
# 7

# %%
df.mean()
# Out:
# x1    31.428571
# x2    45.142857
# x3    30.000000
# x4    38.142857
# x5    56.571429
# dtype: float64

# %%
df.x1.mean()
# Out:
# 31.428571428571427

# %%
df.x2.mean()
# Out:
# 45.142857142857146

# %%
df.median()
# Out:
# x1    33.0
# x2    39.0
# x3    19.0
# x4    28.0
# x5    50.0
# dtype: float64

# %%
df.x3.median()
# Out:
# 19.0

# %%
df.min()
# Out:
# x1     0
# x2    13
# x3     6
# x4     5
# x5    41
# dtype: int32

# %%
df.x4.min()
# Out:
# 5

# %%
df.idxmin()
# Out:
# x1    4
# x2    3
# x3    4
# x4    1
# x5    1
# dtype: int64

# %%
df.x5.idxmin()
# Out:
# 1

# %%
df.x4.idxmin()
# Out:
# 1

# %%
df.std()
# Out:
# x1    30.880723
# x2    23.154759
# x3    21.779195
# x4    31.360424
# x5    18.804761
# dtype: float64

# %%
df[["x1","x2"]].std()
# Out:
# x1    30.880723
# x2    23.154759
# dtype: float64

# %%
df.var()
# Out:
# x1    953.619048
# x2    536.142857
# x3    474.333333
# x4    983.476190
# x5    353.619048
# dtype: float64

# %%
df[["x1","x2"]].var()
# Out:
# x1    953.619048
# x2    536.142857
# dtype: float64

# %%
df.sum(axis=0)
# Out:
# x1    220
# x2    316
# x3    210
# x4    267
# x5    396
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    224
# 1    168
# 2    255
# 3    256
# 4    101
# 5    211
# 6    194
# dtype: int64

# %%
df.x1.sum()
# Out:
# 220

# %%
df.describe()
# Out:
#               x1         x2         x3         x4         x5
# count   7.000000   7.000000   7.000000   7.000000   7.000000
# mean   31.428571  45.142857  30.000000  38.142857  56.571429
# std    30.880723  23.154759  21.779195  31.360424  18.804761
# min     0.000000  13.000000   6.000000   5.000000  41.000000
# 25%     6.500000  35.000000  15.000000  16.000000  45.500000
# 50%    33.000000  39.000000  19.000000  28.000000  50.000000
# 75%    43.500000  56.000000  46.000000  55.000000  59.500000
# max    87.000000  82.000000  63.000000  92.000000  95.000000

# %%
df.describe().T
# Out:
#     count       mean        std   min   25%   50%   75%   max
# x1    7.0  31.428571  30.880723   0.0   6.5  33.0  43.5  87.0
# x2    7.0  45.142857  23.154759  13.0  35.0  39.0  56.0  82.0
# x3    7.0  30.000000  21.779195   6.0  15.0  19.0  46.0  63.0
# x4    7.0  38.142857  31.360424   5.0  16.0  28.0  55.0  92.0
# x5    7.0  56.571429  18.804761  41.0  45.5  50.0  59.5  95.0

# %% [markdown]
#    # Groupby & Aggregation

# %% [markdown]
# # DataFrame.groupby()

# %% [raw]
# groupby() yöntemi, DataFrame'i bir eşleyici kullanarak veya bir dizi sütuna göre gruplar. Groupby işlemi, nesneyi bölme, bir işlev uygulama ve sonuçları birleştirmenin bir kombinasyonunu içerir. Bu, büyük miktarda veriyi gruplandırmak ve bu gruplar üzerindeki işlemleri hesaplamak için kullanılabilir.

# %% [raw]
# Başka bir deyişle, groupby() yöntemi, veri satırlarını birlikte gruplandırmanıza ve toplama işlevlerini çağırmanıza olanak tanır.

# %% [raw]
# DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=NoDefault.no_default, observed=False, dropna=True)

# %%
data = {'Company':['GOOG', 'GOOG', 'MSFT', 'MSFT', 'GOOG', 'MSFT', 'GOOG', 'MSFT'],
        'Department':['HR', 'IT', 'IT', 'HR', 'HR', 'IT', 'IT', 'HR'],
        'Person':['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah', 'Tom', 'Terry'],
        'Age':[30, 28, 35, 40, 42, 25, 32, 48],
        'Sales':[200, 120, 340, 124, 243, 350, 180, 220]}

# %%
df1=pd.DataFrame(data)
df1
# Out:
#   Company Department   Person  Age  Sales
# 0    GOOG         HR      Sam   30    200
# 1    GOOG         IT  Charlie   28    120
# 2    MSFT         IT      Amy   35    340
# 3    MSFT         HR  Vanessa   40    124
# 4    GOOG         HR     Carl   42    243
# 5    MSFT         IT    Sarah   25    350
# 6    GOOG         IT      Tom   32    180
# 7    MSFT         HR    Terry   48    220

# %%
df1.groupby("Company")

# %%
df1.groupby("Company").mean()
# Out:
#           Age   Sales
# Company
# GOOG     33.0  185.75
# MSFT     37.0  258.50

# %%
df1.groupby("Company")["Sales"].mean()
# Out:
# Company
# GOOG    185.75
# MSFT    258.50
# Name: Sales, dtype: float64

# %%
df1.groupby("Company")[["Sales"]].mean()
# Out:
#           Sales
# Company
# GOOG     185.75
# MSFT     258.50

# %%
df1.groupby(["Company","Department"]).mean()
# Out:
#                      Age  Sales
# Company Department
# GOOG    HR          36.0  221.5
#         IT          30.0  150.0
# MSFT    HR          44.0  172.0
#         IT          30.0  345.0

# %%
df1.groupby(["Company","Department"])[["Sales"]].mean()
# Out:
#                     Sales
# Company Department
# GOOG    HR          221.5
#         IT          150.0
# MSFT    HR          172.0
#         IT          345.0

# %%
df1.groupby(["Company","Department"])[["Age"]].max()
# Out:
#                     Age
# Company Department
# GOOG    HR           42
#         IT           32
# MSFT    HR           48
#         IT           35

# %%
df1.groupby(["Company","Department"])[["Sales"]].describe()
# Out:
#                    Sales                                                  \
#                    count   mean        std    min     25%    50%     75%
# Company Department
# GOOG    HR           2.0  221.5  30.405592  200.0  210.75  221.5  232.25
#         IT           2.0  150.0  42.426407  120.0  135.00  150.0  165.00
# MSFT    HR           2.0  172.0  67.882251  124.0  148.00  172.0  196.00
#         IT           2.0  345.0   7.071068  340.0  342.50  345.0  347.50
#
#
#                       max
# Company Department
# GOOG    HR          243.0
#         IT          180.0
# MSFT    HR          220.0
#         IT          350.0

# %% [markdown]
# Artık satırları bir sütun adına göre gruplandırmak için .groupby() yöntemini kullanabilirsiniz. Örneğin Şirket bazında gruplandıralım. Bu, bir DataFrameGroupBy nesnesi yaratacaktır:

# %%
df1.groupby("Company")

# %%
by_comp=df1.groupby("Company")

# %%
by_comp.mean()
# Out:
#           Age   Sales
# Company
# GOOG     33.0  185.75
# MSFT     37.0  258.50

# %% [markdown]
# # Useful Operations

# %% [raw]
# .aggregate()
# .filter()
# .transform()
# .apply()
# .applymap()
# .map()
# .pivot() & .pivot_table()
# .stack() & .unstack()

# %% [markdown]
# # DataFrame.agg()

# %% [raw]
# ``DataFrame.aggregate(func=None, axis=0, *args, kwargs)``**

# %% [markdown]
# scalar : when Series.agg is called with single function
#
# Series : when DataFrame.agg is called with a single function
#
# DataFrame : when DataFrame.agg is called with several functions (Returns scalar, Series or DataFrame).

# %%
df2 = pd.DataFrame({'groups': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
                   'var1': [10, 23, 33, 22, 11, 99, 76, 84, 45],
                   'var2': [100, 253, 333, 262, 111, 969, 405, 578, 760]})
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.agg([sum,min])
# Out:
#         groups  var1  var2
# sum  ABCABCABC   403  3771
# min          A    10   100

# %%
df2[["var1","var2"]].agg([sum,min])
# Out:
#      var1  var2
# sum   403  3771
# min    10   100

# %%
df2.agg({"var1":sum,"var2":min})
# Out:
# var1    403
# var2    100
# dtype: int64

# %%
df2.agg({"var1":[sum],"var2":[min]})
# Out:
#       var1   var2
# sum  403.0    NaN
# min    NaN  100.0

# %%
df2.agg({"var1":[sum,np.mean] , "var2":[min,max]})
# Out:
#             var1   var2
# sum   403.000000    NaN
# mean   44.777778    NaN
# min          NaN  100.0
# max          NaN  969.0

# %% [markdown]
# # DataFrame.groupby().agg()

# %% [raw]
# DataFrameGroupBy.agg(arg, *args, kwargs)

# %%
df2.groupby("groups").aggregate([np.min, np.median , np.max])
# Out:
#        var1             var2
#        amin median amax amin median amax
# groups
# A        10     22   76  100    262  405
# B        11     23   84  111    253  578
# C        33     45   99  333    760  969

# %%
df2.groupby("groups").agg([np.min, "median", max])
# Out:
#        var1            var2
#        amin median max amin median  max
# groups
# A        10     22  76  100    262  405
# B        11     23  84  111    253  578
# C        33     45  99  333    760  969

# %%
df2.groupby("groups")["var1"].agg([min, "max"])
# Out:
#         min  max
# groups
# A        10   76
# B        11   84
# C        33   99

# %% [markdown]
# # DataFrame.filter()

# %% [raw]
# Pandas Dataframe.filter(), belirli bir dizindeki etiketlere göre DataFrame sütunlarını veya satırlarını alt kümelemek için kullanılan yerleşik bir işlevdir.

# %% [raw]
# DataFrame filter(), ayrıntılı dizin etiketlerine göre DataFrame satırlarının veya sütunlarının alt kümesini döndürür

# %% [raw]
# Unutulmaması gereken bir şey, bu rutinin içeriğinde bir DataFrame'i filtrelemediğini unutmayın. filter() işlevi, indexPandas Resmi Belgelerinin etiketlerine uygulanır.

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.filter(["groups","var1"])
# Out:
#   groups  var1
# 0      A    10
# 1      B    23
# 2      C    33
# 3      A    22
# 4      B    11
# 5      C    99
# 6      A    76
# 7      B    84
# 8      C    45

# %%
df2[["groups","var1"]]
# Out:
#   groups  var1
# 0      A    10
# 1      B    23
# 2      C    33
# 3      A    22
# 4      B    11
# 5      C    99
# 6      A    76
# 7      B    84
# 8      C    45

# %%
df2.filter(regex="^gro", axis=1)
# Out:
#   groups
# 0      A
# 1      B
# 2      C
# 3      A
# 4      B
# 5      C
# 6      A
# 7      B
# 8      C

# %%
df2.filter(regex="^var", axis=1)
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df2.filter(like="1", axis=1)
# Out:
#    var1
# 0    10
# 1    23
# 2    33
# 3    22
# 4    11
# 5    99
# 6    76
# 7    84
# 8    45

# %%
df2.filter(like="2",axis=0)
# Out:
#   groups  var1  var2
# 2      C    33   333

# %%
df2["groups"]
# Out:
# 0    A
# 1    B
# 2    C
# 3    A
# 4    B
# 5    C
# 6    A
# 7    B
# 8    C
# Name: groups, dtype: object

# %% [raw]
# ## DataFrame.groupby().filter()

# %%
df2.groups.unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df2.groupby("groups").mean()
# Out:
#              var1        var2
# groups
# A       36.000000  255.666667
# B       39.333333  314.000000
# C       59.000000  687.333333

# %%
def filter_func(x):
    return x["var1"].mean() > 39

#ortalaması 39 dan büyük olanları getir

# %%
df2.groupby("groups").filter(filter_func)

#filter_func bir değişken olarak verildi ve filter fonksiyonu aracılığı ile çağırıldı
#df2 deki var1 de ortalaması 39 dan büyük olanları getir dendi.
#bu şartı sağlayan gruplar 67. satırda da görüldüğü gibi B ve C grupları
# Out:
#   groups  var1  var2
# 1      B    23   253
# 2      C    33   333
# 4      B    11   111
# 5      C    99   969
# 7      B    84   578
# 8      C    45   760

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby("groups").filter(lambda x:x["var2"].sum() < 800)

#toplamı 800 den küçük olanları getir . bu da a grubunda yer alan satırlar için geçerli bir condiditon
# Out:
#   groups  var1  var2
# 0      A    10   100
# 3      A    22   262
# 6      A    76   405

# %% [markdown]
# # transform()

# %% [raw]
# Datamızı fönüştürür.
# Bu dönüşümün sonunda aynı uzunlukta bir dataframe veriri. Eğer bir sütun için tarnsform işlemi yapıyorsak o sütun kadar uzunlukta bir sütun döndürür.

# %%
ornek_df=pd.DataFrame({"A":range(3), "B":range(1,4)})
ornek_df
# Out:
#    A  B
# 0  0  1
# 1  1  2
# 2  2  3

# %%
ornek_df.transform(lambda x: x+1)
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
ornek_df.transform(lambda x:x**2)
# Out:
#    A  B
# 0  0  1
# 1  1  4
# 2  4  9

# %%
s=pd.Series(range(3))
s
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
s.transform([np.sqrt , np.exp])
# Out:
#        sqrt       exp
# 0  0.000000  1.000000
# 1  1.000000  2.718282
# 2  1.414214  7.389056

# %%
df2.groupby("groups")["var1"].mean()
# Out:
# groups
# A    36.000000
# B    39.333333
# C    59.000000
# Name: var1, dtype: float64

# %% [raw]
# Bir datasetinde eksik bilgiler var. Örneğinn fiyat bilgisi bazı datalar için yok. Ortalama değerleri bulup eksik olan fiyat kısımlarına yerleştirebiliriz.
# Aşağıdaki işlem bu şekilde açıklanabilir.
# var1 için genel ortalaması alındı ve A grubu için olan  ortalamalar B grubu için olan ortalamalar vs tesbit ediliyor ve dolduruluyor.

# %%
df2.groupby("groups")["var1"].transform("mean")
# Out:
# 0    36.000000
# 1    39.333333
# 2    59.000000
# 3    36.000000
# 4    39.333333
# 5    59.000000
# 6    36.000000
# 7    39.333333
# 8    59.000000
# Name: var1, dtype: float64

# %%
df_num=df2.iloc[:,1:3]
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.transform(lambda x:x+10)
# Out:
#    var1  var2
# 0    20   110
# 1    33   263
# 2    43   343
# 3    32   272
# 4    21   121
# 5   109   979
# 6    86   415
# 7    94   588
# 8    55   770

# %% [raw]
#  self ile aynı uzunluğa sahip olması gereken bir DataFrame döndürür. Standardizasyon(ortalama 0 std 1) Normalizasyon (0-1)

# %%
df_num.transform(lambda x: (x - x.mean()) / x.std())
# Out:
#        var1      var2
# 0 -1.040605 -1.078044
# 1 -0.651625 -0.560989
# 2 -0.352409 -0.290633
# 3 -0.681547 -0.530573
# 4 -1.010684 -1.040870
# 5  1.622413  1.858697
# 6  0.934218 -0.047312
# 7  1.173590  0.537332
# 8  0.006649  1.152392

# %%
df_num.var1.transform(lambda x: (x - x.mean()) / x.std())
# Out:
# 0   -1.040605
# 1   -0.651625
# 2   -0.352409
# 3   -0.681547
# 4   -1.010684
# 5    1.622413
# 6    0.934218
# 7    1.173590
# 8    0.006649
# Name: var1, dtype: float64

# %%
df_num.var2.transform(lambda x: (x - x.mean()) / x.std())
# Out:
# 0   -1.078044
# 1   -0.560989
# 2   -0.290633
# 3   -0.530573
# 4   -1.040870
# 5    1.858697
# 6   -0.047312
# 7    0.537332
# 8    1.152392
# Name: var2, dtype: float64

# %%
df_num.var1.transform(np.sqrt)
# Out:
# 0    3.162278
# 1    4.795832
# 2    5.744563
# 3    4.690416
# 4    3.316625
# 5    9.949874
# 6    8.717798
# 7    9.165151
# 8    6.708204
# Name: var1, dtype: float64

# %%
df_num.var1.transform([np.sqrt , np.exp])
# Out:
#        sqrt           exp
# 0  3.162278  2.202647e+04
# 1  4.795832  9.744803e+09
# 2  5.744563  2.146436e+14
# 3  4.690416  3.584913e+09
# 4  3.316625  5.987414e+04
# 5  9.949874  9.889030e+42
# 6  8.717798  1.014800e+33
# 7  9.165151  3.025077e+36
# 8  6.708204  3.493427e+19

# %% [markdown]
# # DataFrame.groupby().transform()

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.groupby("groups")["var1"].mean()
# Out:
# groups
# A    36.000000
# B    39.333333
# C    59.000000
# Name: var1, dtype: float64

# %%
df2.groupby("groups")["var1"].transform("mean")
# Out:
# 0    36.000000
# 1    39.333333
# 2    59.000000
# 3    36.000000
# 4    39.333333
# 5    59.000000
# 6    36.000000
# 7    39.333333
# 8    59.000000
# Name: var1, dtype: float64

# %%
df2["var1_mean_transform"] = df2.groupby("groups")["var1"].transform("mean")

# %%
df2
# Out:
#   groups  var1  var2  var1_mean_transform
# 0      A    10   100            36.000000
# 1      B    23   253            39.333333
# 2      C    33   333            59.000000
# 3      A    22   262            36.000000
# 4      B    11   111            39.333333
# 5      C    99   969            59.000000
# 6      A    76   405            36.000000
# 7      B    84   578            39.333333
# 8      C    45   760            59.000000

# %%
df2["var2_mean_transform"] = df2.groupby("groups")["var2"].transform("mean")

# %%
df2
# Out:
#   groups  var1  var2  var1_mean_transform  var2_mean_transform
# 0      A    10   100            36.000000           255.666667
# 1      B    23   253            39.333333           314.000000
# 2      C    33   333            59.000000           687.333333
# 3      A    22   262            36.000000           255.666667
# 4      B    11   111            39.333333           314.000000
# 5      C    99   969            59.000000           687.333333
# 6      A    76   405            36.000000           255.666667
# 7      B    84   578            39.333333           314.000000
# 8      C    45   760            59.000000           687.333333

# %% [markdown]
# # apply()

# %% [raw]
# Bir DataFrame üzerinde yineleme yapmak için bir döngü kullanmanın bir alternatifi, pandas .apply() yöntemini kullanmaktır. Bu işlev, Python'da bir map() işlevi olarak işlev görür. Bir işlevi girdi olarak alır ve bu işlevi tüm DataFrame'e uygular.

# %% [raw]
# Apply(), DataFrame ekseni boyunca veya Series değerleri üzerinde bir işlev uygulamak için kullanılır. Başka bir deyişle, Pandas.apply()**, kullanıcıların bir işlevi iletmesine ve bunu Pandas serisinin her bir değerine uygulamasına izin verir.

# %% [markdown]
# # Series.apply() - df["col"].apply()

# %%
df3 = pd.DataFrame({'col1':[1, 2, 3, 4],
                    'col2':[444, 555, 666, 444],
                    'col3':['abc', 'def', 'ghi', 'xyz']})
df3
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def squared(x):
    return x**2

# %%
df3["col1"].apply(squared)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %% [raw]
# Yukarıda apply için kare alma aşağıda logaritma alma gibi bazı işlemleri yapmış olduk. İçeride bir for döngüsü döndürüyor gibi oluyor.

# %%
df3["col2"].apply(np.log)
# Out:
# 0    6.095825
# 1    6.318968
# 2    6.501290
# 3    6.095825
# Name: col2, dtype: float64

# %%
df3["col3"].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df3["col3"].apply(lambda x:x[0]*3)
# Out:
# 0    aaa
# 1    ddd
# 2    ggg
# 3    xxx
# Name: col3, dtype: object

# %%
df3["col2"].apply(lambda x: "high" if x > 500 else "low")
# Out:
# 0     low
# 1    high
# 2    high
# 3     low
# Name: col2, dtype: object

# %% [markdown]
# # DataFrame.apply()

# %%
df2
# Out:
#   groups  var1  var2  var1_mean_transform  var2_mean_transform
# 0      A    10   100            36.000000           255.666667
# 1      B    23   253            39.333333           314.000000
# 2      C    33   333            59.000000           687.333333
# 3      A    22   262            36.000000           255.666667
# 4      B    11   111            39.333333           314.000000
# 5      C    99   969            59.000000           687.333333
# 6      A    76   405            36.000000           255.666667
# 7      B    84   578            39.333333           314.000000
# 8      C    45   760            59.000000           687.333333

# %%
df2.drop(["var1_mean_transform","var2_mean_transform"], axis=1 ,inplace=True)

# %%
df2
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    76   405
# 7      B    84   578
# 8      C    45   760

# %%
df2.apply(np.sum)
# Out:
# groups    ABCABCABC
# var1            403
# var2           3771
# dtype: object

# %%
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.apply(np.sum)
# Out:
# var1     403
# var2    3771
# dtype: int64

# %%
df_num.apply(np.sum, axis=1)
# Out:
# 0     110
# 1     276
# 2     366
# 3     284
# 4     122
# 5    1068
# 6     481
# 7     662
# 8     805
# dtype: int64

# %%
df_num.apply(lambda x: x +10)
# Out:
#    var1  var2
# 0    20   110
# 1    33   263
# 2    43   343
# 3    32   272
# 4    21   121
# 5   109   979
# 6    86   415
# 7    94   588
# 8    55   770

# %%
df2.groupby("groups").apply(np.mean)
# Out:
#              var1        var2
# groups
# A       36.000000  255.666667
# B       39.333333  314.000000
# C       59.000000  687.333333

# %% [raw]
# Applymap() yalnızca DataFrame'de bulunur ve DataFrame'in tamamında öğe bazında işlem için kullanılır.
#
# Optimize edilmiştir ve bazı durumlarda apply ()' dan çok daha hızlı çalışır.
#
# Applymap() yöntemi yalnızca, işlevin her öğeye ayrı ayrı uygulandığı bir pandas veri çerçevesinde çalışır.
#
# Apply () yöntemi, işlevin sağlanan işlev türüne göre hem serilere hem de tek tek öğelere uygulanabileceği hem serilere hem de veri çerçevelerine uygulanabilir.

# %% [markdown]
# # DataFrame.applymap()

# %%
df_num
# Out:
#    var1  var2
# 0    10   100
# 1    23   253
# 2    33   333
# 3    22   262
# 4    11   111
# 5    99   969
# 6    76   405
# 7    84   578
# 8    45   760

# %%
df_num.applymap(lambda x:x*5)
# Out:
#    var1  var2
# 0    50   500
# 1   115  1265
# 2   165  1665
# 3   110  1310
# 4    55   555
# 5   495  4845
# 6   380  2025
# 7   420  2890
# 8   225  3800

# %%
df_num.applymap(lambda x: len(str(x)))
# Out:
#    var1  var2
# 0     2     3
# 1     2     3
# 2     2     3
# 3     2     3
# 4     2     3
# 5     2     3
# 6     2     3
# 7     2     3
# 8     2     3

# %%
df_num.apply(lambda x: len(str(x)))
# Out:
# var1     96
# var2    105
# dtype: int64

# %% [markdown]
# # Series.map()

# %% [raw]
# Python's map() is a built-in function that allows you to process and transform all the items in an iterable without using an explicit for loop, a technique commonly known as mapping.
#
# map() is useful when you need to apply a transformation function to each item in an iterable and transform them into a new iterable Source.
#
# The map() function is used to map values of Series according to input correspondence. Used for substituting each value in a Series with another value, that may be derived from a function, a dict or a Series.
#
# map() accepts a dict or a Series. Values that are not found in the dict are converted to NaN, unless the dict has a default value Source.

# %% [markdown]
# ###

# %%
df3
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df3.col1.map({1:"A",2:"B"})
# Out:
# 0      A
# 1      B
# 2    NaN
# 3    NaN
# Name: col1, dtype: object

# %%
s=pd.Series(["fox" ,"cow" , np.nan, "dog"])
s
# Out:
# 0    fox
# 1    cow
# 2    NaN
# 3    dog
# dtype: object

# %%
s.map("I am a {}".format)
# Out:
# 0    I am a fox
# 1    I am a cow
# 2    I am a nan
# 3    I am a dog
# dtype: object

# %%
s.map("I am a {}".format, na_action="ignore")
# Out:
# 0    I am a fox
# 1    I am a cow
# 2           NaN
# 3    I am a dog
# dtype: object

# %% [raw]
# Apply(), DataFrame ekseni boyunca veya Series değerleri üzerinde bir işlev uygulamak için kullanılır.
#
# applymap() is used to apply a function to a DataFrame elementwise.
#
# map() is used to substitute each value in a Series with another value.

# %% [markdown]
# # .transform() vs .apply()

# %% [raw]
# Both apply() and transform() can be used to manipulate the entire DataFrame.
# Both apply() and transform() support lambda expression.
# Both apply() and transform() can be used for manipulating a single column.

# %%
df5=pd.DataFrame({"A":[1,2,3],"B":[10,20,30]})
df5
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df5.apply(lambda x: x+10)
# Out:
#     A   B
# 0  11  20
# 1  12  30
# 2  13  40

# %%
df5["B_ap"] = df5["B"].apply(lambda x: x+10)
df5["B_tr"] = df5["B"].transform(lambda x: x+10)

# %%
df5
# Out:
#    A   B  B_ap  B_tr
# 0  1  10    20    20
# 1  2  20    30    30
# 2  3  30    40    40

# %% [markdown]
# Differences between .apply() and .transform() when manupulating data
#
#     transform() cannot produce aggregated results.
#     apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %%
df5= df5[["A","B"]]
df5
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df5.apply(lambda x: x["B"] - x["A"] ,  axis=1)
# Out:
# 0     9
# 1    18
# 2    27
# dtype: int64

# %%
df5.apply(lambda x: x["B"]**2, axis=1)
# Out:
# 0    100
# 1    400
# 2    900
# dtype: int64

# %% [markdown]
# Differences Between .apply() and .transform() when using them in conjunction with groupby()
#
#     transform() returns a DataFrame that has the same length as the input, but apply() cannot
#     apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %%
df6 = pd.DataFrame({'key': ['a','b','c'] * 3,
                    'A': np.arange(9),
                    'B': [1,2,3] * 3})
df6
# Out:
#   key  A  B
# 0   a  0  1
# 1   b  1  2
# 2   c  2  3
# 3   a  3  1
# 4   b  4  2
# 5   c  5  3
# 6   a  6  1
# 7   b  7  2
# 8   c  8  3

# %%
df6.groupby("key")["A"].sum()
# Out:
# key
# a     9
# b    12
# c    15
# Name: A, dtype: int32

# %%
df6.groupby("key")["A"].transform(lambda x: x.sum())
# Out:
# 0     9
# 1    12
# 2    15
# 3     9
# 4    12
# 5    15
# 6     9
# 7    12
# 8    15
# Name: A, dtype: int32

# %%
df6
# Out:
#   key  A  B
# 0   a  0  1
# 1   b  1  2
# 2   c  2  3
# 3   a  3  1
# 4   b  4  2
# 5   c  5  3
# 6   a  6  1
# 7   b  7  2
# 8   c  8  3

# %%
df6.groupby("key").apply(lambda x: x["B"]- x["A"])
# Out:
# key
# a    0    1
#      3   -2
#      6   -5
# b    1    1
#      4   -2
#      7   -5
# c    2    1
#      5   -2
#      8   -5
# dtype: int64

# %% [markdown]
# # pivot() vs pivot_table()

# %% [raw]
# pivot_table()
#
#     pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True).
#
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.

# %% [raw]
# pivot()
#
#     DataFrame.pivot(index=None, columns=None, values=None).
#
#     Return reshaped DataFrame organized by given index / column values.
#
#     Reshape data (produce a “pivot” table) based on column values. Uses unique values from specified index / columns to form axes of the resulting DataFrame.
#
#     This function does not support data aggregation, multiple values will result in a MultiIndex in the columns.

# %% [raw]
# Differences
#
#     Pivot_table is a generalization of pivot that CAN handle duplicate values for one pivoted index/column pair. However, pivot() is used for pivoting without aggregation. Therefore, it CANNOT deal with duplicate values for one index/column pair.
#
#     Pivot_table will only allow numeric types as "values=", whereas pivot will take string types as "values=".
#
#     Pivot_table also supports using multiple columns for the index.

# %%
data = {'gender':['male', 'female', 'female', 'male', 'female', 'male'],
        'sport':['tennis', 'tennis', 'basketball', 'football', 'voleyball', 'basketball'],
        'status':["professional","professional","professional","amateur","amateur","amateur"],
        'age':[20, 24, 26, 23, 22, 21],
        'height':[185, 172, 175, 178, 182, 196],
        'weight':[83, 58, 62, 80, 65, 90]}

df7 = pd.DataFrame(data)

df7
# Out:
#    gender       sport        status  age  height  weight
# 0    male      tennis  professional   20     185      83
# 1  female      tennis  professional   24     172      58
# 2  female  basketball  professional   26     175      62
# 3    male    football       amateur   23     178      80
# 4  female   voleyball       amateur   22     182      65
# 5    male  basketball       amateur   21     196      90

# %%
df7.pivot_table(index ="gender",
               columns="sport",
               values=["age"],
               aggfunc="mean")
# Out:
#               age
# sport  basketball football tennis voleyball
# gender
# female       26.0      NaN   24.0      22.0
# male         21.0     23.0   20.0       NaN

# %%
df7.pivot_table(index="gender",
               columns="sport",
               values=["age","height","weight"],
               aggfunc="mean")
# Out:
#               age                               height                  \
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female       26.0      NaN   24.0      22.0      175.0      NaN  172.0
# male         21.0     23.0   20.0       NaN      196.0    178.0  185.0
#
#                      weight
# sport  voleyball basketball football tennis voleyball
# gender
# female     182.0       62.0      NaN   58.0      65.0
# male         NaN       90.0     80.0   83.0       NaN

# %%
df7.pivot(index='gender',
          columns='sport',
          values=['age','height','weight'])
# Out:
#               age                               height                  \
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female       26.0      NaN   24.0      22.0      175.0      NaN  172.0
# male         21.0     23.0   20.0       NaN      196.0    178.0  185.0
#
#                      weight
# sport  voleyball basketball football tennis voleyball
# gender
# female     182.0       62.0      NaN   58.0      65.0
# male         NaN       90.0     80.0   83.0       NaN

# %% [markdown]
# 1.) If we have categoric values for value parameter, we can use just "pivot" method.

# %%
df7.pivot(index='gender',
          columns='sport',
          values='status')
# Out:
# sport     basketball football        tennis voleyball
# gender
# female  professional      NaN  professional   amateur
# male         amateur  amateur  professional       NaN

# %% [markdown]
# 2.) If we have dublicate values in column selected for index parameter, we can use just "pivot_table" method.

# %%
df7
# Out:
#    gender       sport        status  age  height  weight
# 0    male      tennis  professional   20     185      83
# 1  female      tennis  professional   24     172      58
# 2  female  basketball  professional   26     175      62
# 3    male    football       amateur   23     178      80
# 4  female   voleyball       amateur   22     182      65
# 5    male  basketball       amateur   21     196      90

# %%
df7.loc[2,"sport"]="tennis"
df7
# Out:
#    gender       sport        status  age  height  weight
# 0    male      tennis  professional   20     185      83
# 1  female      tennis  professional   24     172      58
# 2  female      tennis  professional   26     175      62
# 3    male    football       amateur   23     178      80
# 4  female   voleyball       amateur   22     182      65
# 5    male  basketball       amateur   21     196      90

# %%
df7.pivot_table(index='gender',
                columns='sport',
                values=['age','height','weight'],
                aggfunc='mean')
# Out:
#               age                               height                  \
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female        NaN      NaN   25.0      22.0        NaN      NaN  173.5
# male         21.0     23.0   20.0       NaN      196.0    178.0  185.0
#
#                      weight
# sport  voleyball basketball football tennis voleyball
# gender
# female     182.0        NaN      NaN   60.0      65.0
# male         NaN       90.0     80.0   83.0       NaN

# %%
# if we want to get a result with pivot method, we have to remove index parameter

df7.pivot(columns='sport',
          values=['age','height','weight'])
# Out:
#              age                               height                  \
# sport basketball football tennis voleyball basketball football tennis
# 0            NaN      NaN   20.0       NaN        NaN      NaN  185.0
# 1            NaN      NaN   24.0       NaN        NaN      NaN  172.0
# 2            NaN      NaN   26.0       NaN        NaN      NaN  175.0
# 3            NaN     23.0    NaN       NaN        NaN    178.0    NaN
# 4            NaN      NaN    NaN      22.0        NaN      NaN    NaN
# 5           21.0      NaN    NaN       NaN      196.0      NaN    NaN
#
#                     weight
# sport voleyball basketball football tennis voleyball
# 0           NaN        NaN      NaN   83.0       NaN
# 1           NaN        NaN      NaN   58.0       NaN
# 2           NaN        NaN      NaN   62.0       NaN
# 3           NaN        NaN     80.0    NaN       NaN
# 4         182.0        NaN      NaN    NaN      65.0
# 5           NaN       90.0      NaN    NaN       NaN

# %% [markdown]
# We can get same results with both groupby and pivot_table

# %%
df7.groupby(["gender","sport"]).mean()
# Out:
#                     age  height  weight
# gender sport
# female tennis      25.0   173.5    60.0
#        voleyball   22.0   182.0    65.0
# male   basketball  21.0   196.0    90.0
#        football    23.0   178.0    80.0
#        tennis      20.0   185.0    83.0

# %%
df7.pivot_table(index=['gender', 'sport'],
                #columns = "status",
                values=['age','height','weight'],
                aggfunc='mean')
# Out:
#                    age  height  weight
# gender sport
# female tennis       25   173.5      60
#        voleyball    22   182.0      65
# male   basketball   21   196.0      90
#        football     23   178.0      80
#        tennis       20   185.0      83

# %% [markdown]
# # .stack() & .unstack()

# %% [markdown]
# Pandas python'da stack() ve unstack() işlevini kullanarak yeniden şekillendirme: Pandas'ta stack() işlevini kullanarak verileri yeniden şekillendirmek, verileri yığın biçimine dönüştürür .i.e. sütun satır bazında istiflenir.

# %% [markdown]
# Birden fazla sütun başlığı mevcut olduğunda, belirli bir sütun başlığını seviyeyi belirterek istifleyebiliriz. pandasdaki unstack() işlevi, verileri yığınsız biçime dönüştürür.

# %% [markdown]
# # stack()

# %% [raw]
# DataFrame.stack(level=- 1, dropna=True)
#
#     Stack the prescribed level(s) from columns to index.
#     Return a reshaped DataFrame or Series having a multi-level index with one or more new inner-most levels compared to the current DataFrame.
#     The new inner-most levels are created by pivoting the columns of the current dataframe:
#         if the columns have a single level, the output is a Series;
#         if the columns have multiple levels, the new index level(s) is (are) taken from the prescribed level(s) and the output is a DataFrame.

# %%
df7
# Out:
#    gender       sport        status  age  height  weight
# 0    male      tennis  professional   20     185      83
# 1  female      tennis  professional   24     172      58
# 2  female      tennis  professional   26     175      62
# 3    male    football       amateur   23     178      80
# 4  female   voleyball       amateur   22     182      65
# 5    male  basketball       amateur   21     196      90

# %%
df7["level"]=["high","high","low","high","low","low"]
df7
# Out:
#    gender       sport        status  age  height  weight level
# 0    male      tennis  professional   20     185      83  high
# 1  female      tennis  professional   24     172      58  high
# 2  female      tennis  professional   26     175      62   low
# 3    male    football       amateur   23     178      80  high
# 4  female   voleyball       amateur   22     182      65   low
# 5    male  basketball       amateur   21     196      90   low

# %%
df8 = df7.pivot_table(index=['gender','sport'],
                columns=["status","level"], 
                values=['age','height','weight'],
                aggfunc='mean')

df8
# Out:
#                       age                           height         \
# status            amateur       professional       amateur
# level                high   low         high   low    high    low
# gender sport
# female tennis         NaN   NaN         24.0  26.0     NaN    NaN
#        voleyball      NaN  22.0          NaN   NaN     NaN  182.0
# male   basketball     NaN  21.0          NaN   NaN     NaN  196.0
#        football      23.0   NaN          NaN   NaN   178.0    NaN
#        tennis         NaN   NaN         20.0   NaN     NaN    NaN
#
#                                        weight
# status            professional        amateur       professional
# level                     high    low    high   low         high   low
# gender sport
# female tennis            172.0  175.0     NaN   NaN         58.0  62.0
#        voleyball           NaN    NaN     NaN  65.0          NaN   NaN
# male   basketball          NaN    NaN     NaN  90.0          NaN   NaN
#        football            NaN    NaN    80.0   NaN          NaN   NaN
#        tennis            185.0    NaN     NaN   NaN         83.0   NaN

# %%
df8.stack()
# Out:
#                             age               height               weight  \
# status                  amateur professional amateur professional amateur
# gender sport      level
# female tennis     high      NaN         24.0     NaN        172.0     NaN
#                   low       NaN         26.0     NaN        175.0     NaN
#        voleyball  low      22.0          NaN   182.0          NaN    65.0
# male   basketball low      21.0          NaN   196.0          NaN    90.0
#        football   high     23.0          NaN   178.0          NaN    80.0
#        tennis     high      NaN         20.0     NaN        185.0     NaN
#
#
# status                  professional
# gender sport      level
# female tennis     high          58.0
#                   low           62.0
#        voleyball  low            NaN
# male   basketball low            NaN
#        football   high           NaN
#        tennis     high          83.0

# %%
df8.stack(level=-1)
# Out:
#                             age               height               weight  \
# status                  amateur professional amateur professional amateur
# gender sport      level
# female tennis     high      NaN         24.0     NaN        172.0     NaN
#                   low       NaN         26.0     NaN        175.0     NaN
#        voleyball  low      22.0          NaN   182.0          NaN    65.0
# male   basketball low      21.0          NaN   196.0          NaN    90.0
#        football   high     23.0          NaN   178.0          NaN    80.0
#        tennis     high      NaN         20.0     NaN        185.0     NaN
#
#
# status                  professional
# gender sport      level
# female tennis     high          58.0
#                   low           62.0
#        voleyball  low            NaN
# male   basketball low            NaN
#        football   high           NaN
#        tennis     high          83.0

# %%
df8.stack(level=-1, dropna=False)
# Out:
#                             age               height               weight  \
# status                  amateur professional amateur professional amateur
# gender sport      level
# female tennis     high      NaN         24.0     NaN        172.0     NaN
#                   low       NaN         26.0     NaN        175.0     NaN
#        voleyball  high      NaN          NaN     NaN          NaN     NaN
#                   low      22.0          NaN   182.0          NaN    65.0
# male   basketball high      NaN          NaN     NaN          NaN     NaN
#                   low      21.0          NaN   196.0          NaN    90.0
#        football   high     23.0          NaN   178.0          NaN    80.0
#                   low       NaN          NaN     NaN          NaN     NaN
#        tennis     high      NaN         20.0     NaN        185.0     NaN
#                   low       NaN          NaN     NaN          NaN     NaN
#
#
# status                  professional
# gender sport      level
# female tennis     high          58.0
#                   low           62.0
#        voleyball  high           NaN
#                   low            NaN
# male   basketball high           NaN
#                   low            NaN
#        football   high           NaN
#                   low            NaN
#        tennis     high          83.0
#                   low            NaN

# %%
df8.stack(level=[-1, -2])
# Out:
#                                        age  height  weight
# gender sport      level status
# female tennis     high  professional  24.0   172.0    58.0
#                   low   professional  26.0   175.0    62.0
#        voleyball  low   amateur       22.0   182.0    65.0
# male   basketball low   amateur       21.0   196.0    90.0
#        football   high  amateur       23.0   178.0    80.0
#        tennis     high  professional  20.0   185.0    83.0

# %% [markdown]
# # .unstack()

# %% [raw]
# DataFrame.unstack(level=- 1, fill_value=None)
#
#     Pivot a level of the (necessarily hierarchical) index labels.
#     Returns a DataFrame having a new level of column labels whose inner-most level consists of the pivoted index labels.
#     If the index is not a MultiIndex, the output will be a Series.

# %% [raw]
# unstack() function pivots a level of the (necessarily hierarchical) index labels, returning a DataFrame having a new level of column labels whose inner-most level consists of the pivoted index labels

# %%
df8
# Out:
#                       age                           height         \
# status            amateur       professional       amateur
# level                high   low         high   low    high    low
# gender sport
# female tennis         NaN   NaN         24.0  26.0     NaN    NaN
#        voleyball      NaN  22.0          NaN   NaN     NaN  182.0
# male   basketball     NaN  21.0          NaN   NaN     NaN  196.0
#        football      23.0   NaN          NaN   NaN   178.0    NaN
#        tennis         NaN   NaN         20.0   NaN     NaN    NaN
#
#                                        weight
# status            professional        amateur       professional
# level                     high    low    high   low         high   low
# gender sport
# female tennis            172.0  175.0     NaN   NaN         58.0  62.0
#        voleyball           NaN    NaN     NaN  65.0          NaN   NaN
# male   basketball          NaN    NaN     NaN  90.0          NaN   NaN
#        football            NaN    NaN    80.0   NaN          NaN   NaN
#        tennis            185.0    NaN     NaN   NaN         83.0   NaN

# %%
df8.unstack()
# Out:
#               age                                                       \
# status    amateur
# level        high                                  low
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female        NaN      NaN    NaN       NaN        NaN      NaN    NaN
# male          NaN     23.0    NaN       NaN       21.0      NaN    NaN
#
#                                         ...  weight                         \
# status           professional           ... amateur           professional
# level                    high           ...     low                   high
# sport  voleyball   basketball football  ...  tennis voleyball   basketball
# gender                                  ...
# female      22.0          NaN      NaN  ...     NaN      65.0          NaN
# male         NaN          NaN      NaN  ...     NaN       NaN          NaN
#
#
# status
# level                                   low
# sport  football tennis voleyball basketball football tennis voleyball
# gender
# female      NaN   58.0       NaN        NaN      NaN   62.0       NaN
# male        NaN   83.0       NaN        NaN      NaN    NaN       NaN
#
# [2 rows x 48 columns]

# %%
df8.unstack(level=-1 )
# Out:
#               age                                                       \
# status    amateur
# level        high                                  low
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female        NaN      NaN    NaN       NaN        NaN      NaN    NaN
# male          NaN     23.0    NaN       NaN       21.0      NaN    NaN
#
#                                         ...  weight                         \
# status           professional           ... amateur           professional
# level                    high           ...     low                   high
# sport  voleyball   basketball football  ...  tennis voleyball   basketball
# gender                                  ...
# female      22.0          NaN      NaN  ...     NaN      65.0          NaN
# male         NaN          NaN      NaN  ...     NaN       NaN          NaN
#
#
# status
# level                                   low
# sport  football tennis voleyball basketball football tennis voleyball
# gender
# female      NaN   58.0       NaN        NaN      NaN   62.0       NaN
# male        NaN   83.0       NaN        NaN      NaN    NaN       NaN
#
# [2 rows x 48 columns]

# %%
df8.unstack(level=-1, fill_value="-") # Replace NaN with this value if the unstack produces missing values.
# Out:
#               age                                                       \
# status    amateur
# level        high                                  low
# sport  basketball football tennis voleyball basketball football tennis
# gender
# female          -        -    NaN       NaN          -        -    NaN
# male          NaN     23.0    NaN         -       21.0      NaN    NaN
#
#                                         ...  weight                         \
# status           professional           ... amateur           professional
# level                    high           ...     low                   high
# sport  voleyball   basketball football  ...  tennis voleyball   basketball
# gender                                  ...
# female      22.0            -        -  ...     NaN      65.0            -
# male           -          NaN      NaN  ...     NaN         -          NaN
#
#
# status
# level                                   low
# sport  football tennis voleyball basketball football tennis voleyball
# gender
# female        -   58.0       NaN          -        -   62.0       NaN
# male        NaN   83.0         -        NaN      NaN    NaN         -
#
# [2 rows x 48 columns]
